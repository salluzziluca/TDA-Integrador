# %%
# Imports necesarios para el notebook
import random

from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import scipy as sp
from John_Jellicoe import algoritmo_JJ

from auxiliares import generate_test_case

from util import time_algorithm

# Siempre seteamos la seed de aleatoridad para que los # resultados sean reproducibles
random.seed(12345)
np.random.seed(12345)

sns.set_theme()

# %%
# Generate test sizes
import time

x = np.linspace(1000, 10000, 50).astype(int)

results = {}

for size in x:
    start_time = time.time()
    n, m, ship_lengths, row_restrictions, col_restrictions = generate_test_case(max_size=size)
    algoritmo_JJ(n, m, ship_lengths, row_restrictions, col_restrictions)
    end_time = time.time()
    results[size] = end_time - start_time

print(results)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 11
#       9 start_time = time.time()
#      10 n, m, ship_lengths, row_restrictions, col_restrictions = generate_test_case(max_size=size)
# ---> 11 algoritmo_JJ(n, m, ship_lengths, row_restrictions, col_restrictions)
#      12 end_time = time.time()
#      13 results[size] = end_time - start_time
#
# File d:\AAlmacenamiento\UBA\tda\TDA-Integrador\parte5\John_Jellicoe.py:86, in algoritmo_JJ(n, m, ship_lengths, row_restrictions, col_restrictions)
#      83 if col_restrictions[target_col] >= ship:  # Verificar si la columna puede acomodar el barco
#      84     for start_row in range(n):
#      85         # Asegurar que todas las filas involucradas tienen suficiente demanda
# ---> 86         if all(0 <= start_row + i < n and row_restrictions[start_row + i] > 0 for i in range(ship)) and can_place_ship(board, start_row, target_col, ship, False):
#      87             place_ship(board, start_row, target_col, ship, False)
#      88             col_restrictions[target_col] -= ship
#
# File d:\AAlmacenamiento\UBA\tda\TDA-Integrador\parte5\John_Jellicoe.py:86, in <genexpr>(.0)
#      83 if col_restrictions[target_col] >= ship:  # Verificar si la columna puede acomodar el barco
#      84     for start_row in range(n):
#      85         # Asegurar que todas las filas involucradas tienen suficiente demanda
# ---> 86         if all(0 <= start_row + i < n and row_restrictions[start_row + i] > 0 for i in range(ship)) and can_place_ship(board, start_row, target_col, ship, False):
#      87             place_ship(board, start_row, target_col, ship, False)
#      88             col_restrictions[target_col] -= ship
#
# KeyboardInterrupt:

# %%
ax: plt.Axes
fig, ax = plt.subplots()
ax.plot(x, [results[i] for i in x], label="Medición")
ax.set_title('Tiempo de ejecución de JJ')
ax.set_xlabel('Tamaño del array')
ax.set_ylabel('Tiempo de ejecución (s)')
# Out:
# Text(0, 0.5, 'Tiempo de ejecución (s)')

# %%
# scipy nos pide una función que recibe primero x y luego los parámetros a ajustar:
f = lambda x, c1, c2: c1 * x * np.log(x) + c2 

c, pcov = sp.optimize.curve_fit(f, x, [results[n] for n in x])

print(f"c_1 = {c[0]}, c_2 = {c[1]}")
r = np.sum((c[0] * x * np.log(x) + c[1] - [results[n] for n in x])**2)
print(f"Error cuadrático total: {r}")
# Out:
# c_1 = 2.767059838946144, c_2 = -19113.666595458984
# Error cuadrático total: 0.0

# %%
ax.plot(x, [c[0] * n * np.log(n) + c[1] for n in x], 'r--', label="Ajuste")
ax.legend()
fig

# %%
ax: plt.Axes
fig, ax = plt.subplots()
errors = [np.abs(c[0] * n * np.log(n) + c[1] - results[n]) for n in x]
ax.plot(x, errors)
ax.set_title('Error de ajuste')
ax.set_xlabel('Tamaño del array')
ax.set_ylabel('Error absoluto (s)')
# Out:
# Text(0, 0.5, 'Error absoluto (s)')
